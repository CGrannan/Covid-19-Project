# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
data = pd.read_csv('owid-covid-data.csv')
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# 1           ...                   1803.987              NaN
# 2           ...                   1803.987              NaN
# 3           ...                   1803.987              NaN
# 4           ...                   1803.987              NaN
#
#    cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                597.029                 9.59             NaN           NaN
# 1                597.029                 9.59             NaN           NaN
# 2                597.029                 9.59             NaN           NaN
# 3                597.029                 9.59             NaN           NaN
# 4                597.029                 9.59             NaN           NaN
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                  37.746                         0.5            64.83
# 1                  37.746                         0.5            64.83
# 2                  37.746                         0.5            64.83
# 3                  37.746                         0.5            64.83
# 4                  37.746                         0.5            64.83
#
#    human_development_index
# 0                    0.511
# 1                    0.511
# 2                    0.511
# 3                    0.511
# 4                    0.511
#
# [5 rows x 59 columns]

# %%
data.isna().sum()
# Out:
# iso_code                                     0
# continent                                 3508
# location                                     0
# date                                         0
# total_cases                                904
# new_cases                                  906
# new_cases_smoothed                        1907
# total_deaths                              9906
# new_deaths                                9748
# new_deaths_smoothed                       1907
# total_cases_per_million                   1285
# new_cases_per_million                     1287
# new_cases_smoothed_per_million            2283
# total_deaths_per_million                 10274
# new_deaths_per_million                   10116
# new_deaths_smoothed_per_million           2283
# reproduction_rate                        13887
# icu_patients                             62971
# icu_patients_per_million                 62971
# hosp_patients                            61562
# hosp_patients_per_million                61562
# weekly_icu_admissions                    69742
# weekly_icu_admissions_per_million        69742
# weekly_hosp_admissions                   69289
# weekly_hosp_admissions_per_million       69289
# new_tests                                38441
# total_tests                              38579
# total_tests_per_thousand                 38579
# new_tests_per_thousand                   38441
# new_tests_smoothed                       33951
# new_tests_smoothed_per_thousand          33951
# positive_rate                            35368
# tests_per_case                           35887
# tests_units                              32666
# total_vaccinations                       68035
# people_vaccinated                        68411
# people_fully_vaccinated                  69133
# new_vaccinations                         68405
# new_vaccinations_smoothed                66924
# total_vaccinations_per_hundred           68035
# people_vaccinated_per_hundred            68411
# people_fully_vaccinated_per_hundred      69133
# new_vaccinations_smoothed_per_million    66924
# stringency_index                         10068
# population                                 390
# population_density                        4592
# median_age                                6317
# aged_65_older                             7057
# aged_70_older                             6679
# gdp_per_capita                            6159
# extreme_poverty                          26520
# cardiovasc_death_rate                     5553
# diabetes_prevalence                       4753
# female_smokers                           19349
# male_smokers                             20050
# handwashing_facilities                   37897
# hospital_beds_per_thousand               10962
# life_expectancy                           3500
# human_development_index                   5574
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70444 entries, 0 to 70443
# Data columns (total 59 columns):
# iso_code                                 70444 non-null object
# continent                                66936 non-null object
# location                                 70444 non-null object
# date                                     70444 non-null object
# total_cases                              69540 non-null float64
# new_cases                                69538 non-null float64
# new_cases_smoothed                       68537 non-null float64
# total_deaths                             60538 non-null float64
# new_deaths                               60696 non-null float64
# new_deaths_smoothed                      68537 non-null float64
# total_cases_per_million                  69159 non-null float64
# new_cases_per_million                    69157 non-null float64
# new_cases_smoothed_per_million           68161 non-null float64
# total_deaths_per_million                 60170 non-null float64
# new_deaths_per_million                   60328 non-null float64
# new_deaths_smoothed_per_million          68161 non-null float64
# reproduction_rate                        56557 non-null float64
# icu_patients                             7473 non-null float64
# icu_patients_per_million                 7473 non-null float64
# hosp_patients                            8882 non-null float64
# hosp_patients_per_million                8882 non-null float64
# weekly_icu_admissions                    702 non-null float64
# weekly_icu_admissions_per_million        702 non-null float64
# weekly_hosp_admissions                   1155 non-null float64
# weekly_hosp_admissions_per_million       1155 non-null float64
# new_tests                                32003 non-null float64
# total_tests                              31865 non-null float64
# total_tests_per_thousand                 31865 non-null float64
# new_tests_per_thousand                   32003 non-null float64
# new_tests_smoothed                       36493 non-null float64
# new_tests_smoothed_per_thousand          36493 non-null float64
# positive_rate                            35076 non-null float64
# tests_per_case                           34557 non-null float64
# tests_units                              37778 non-null object
# total_vaccinations                       2409 non-null float64
# people_vaccinated                        2033 non-null float64
# people_fully_vaccinated                  1311 non-null float64
# new_vaccinations                         2039 non-null float64
# new_vaccinations_smoothed                3520 non-null float64
# total_vaccinations_per_hundred           2409 non-null float64
# people_vaccinated_per_hundred            2033 non-null float64
# people_fully_vaccinated_per_hundred      1311 non-null float64
# new_vaccinations_smoothed_per_million    3520 non-null float64
# stringency_index                         60376 non-null float64
# population                               70054 non-null float64
# population_density                       65852 non-null float64
# median_age                               64127 non-null float64
# aged_65_older                            63387 non-null float64
# aged_70_older                            63765 non-null float64
# gdp_per_capita                           64285 non-null float64
# extreme_poverty                          43924 non-null float64
# cardiovasc_death_rate                    64891 non-null float64
# diabetes_prevalence                      65691 non-null float64
# female_smokers                           51095 non-null float64
# male_smokers                             50394 non-null float64
# handwashing_facilities                   32547 non-null float64
# hospital_beds_per_thousand               59482 non-null float64
# life_expectancy                          66944 non-null float64
# human_development_index                  64870 non-null float64
# dtypes: float64(54), object(5)
# memory usage: 31.7+ MB
