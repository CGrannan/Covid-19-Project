# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
data = pd.read_csv('owid-covid-data.csv')
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
data.shape
# Out:
# (70444, 59)

# %%
data.isna().sum()
# Out:
# iso_code                                     0
# continent                                 3508
# location                                     0
# date                                         0
# total_cases                                904
# new_cases                                  906
# new_cases_smoothed                        1907
# total_deaths                              9906
# new_deaths                                9748
# new_deaths_smoothed                       1907
# total_cases_per_million                   1285
# new_cases_per_million                     1287
# new_cases_smoothed_per_million            2283
# total_deaths_per_million                 10274
# new_deaths_per_million                   10116
# new_deaths_smoothed_per_million           2283
# reproduction_rate                        13887
# icu_patients                             62971
# icu_patients_per_million                 62971
# hosp_patients                            61562
# ...

# %%
data[data.total_cases.isna()].head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 364  OWID_AFR       NaN   Africa  2020-02-13          NaN        0.0
# 739       ALB    Europe  Albania  2020-02-25          NaN        NaN
# 740       ALB    Europe  Albania  2020-02-26          NaN        NaN
# 741       ALB    Europe  Albania  2020-02-27          NaN        NaN
# 742       ALB    Europe  Albania  2020-02-28          NaN        NaN
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 364                 NaN           NaN         0.0                  NaN
# 739                 NaN           NaN         NaN                  NaN
# 740                 NaN           NaN         NaN                  NaN
# 741                 NaN           NaN         NaN                  NaN
# 742                 NaN           NaN         NaN                  NaN
#
#               ...             gdp_per_capita  extreme_poverty  \
# ...

# %%
data[data.new_cases.isna()].head()
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 739      ALB    Europe  Albania  2020-02-25          NaN        NaN
# 740      ALB    Europe  Albania  2020-02-26          NaN        NaN
# 741      ALB    Europe  Albania  2020-02-27          NaN        NaN
# 742      ALB    Europe  Albania  2020-02-28          NaN        NaN
# 743      ALB    Europe  Albania  2020-02-29          NaN        NaN
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 739                 NaN           NaN         NaN                  NaN
# 740                 NaN           NaN         NaN                  NaN
# 741                 NaN           NaN         NaN                  NaN
# 742                 NaN           NaN         NaN                  NaN
# 743                 NaN           NaN         NaN                  NaN
#
#               ...             gdp_per_capita  extreme_poverty  \
# 739           ...                  11803.431              1.1
# ...

# %%
data[(data.total_cases > 0) & (data.new_cases.isna())]
# Out:
#       iso_code      continent       location        date  total_cases  \
# 13377      CHN           Asia          China  2020-01-22        548.0
# 32278      JPN           Asia          Japan  2020-01-22          2.0
# 58753      KOR           Asia    South Korea  2020-01-22          1.0
# 62069      TWN           Asia         Taiwan  2020-01-22          1.0
# 63125      THA           Asia       Thailand  2020-01-22          4.0
# 65188      TUR           Asia         Turkey  2020-12-10    1748567.0
# 66764      USA  North America  United States  2020-01-22          1.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 13377        NaN                 NaN          17.0         NaN
# 32278        NaN                 NaN           NaN         NaN
# 58753        NaN                 NaN           NaN         NaN
# 62069        NaN                 NaN           NaN         NaN
# 63125        NaN                 NaN           NaN         NaN
# ...

# %%
data[data.new_cases_smoothed.isna()].head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
data[data.total_deaths.isna()].head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
data[data.new_deaths.isna()].head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
data[data.new_deaths_smoothed.isna()].head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
data[data.reproduction_rate.isna()].iso_code.value_counts()
# Out:
# OWID_NAM    397
# OWID_ASI    397
# OWID_EUR    396
# OWID_EUN    396
# OWID_OCE    394
# FJI         389
# OWID_INT    381
# OWID_AFR    375
# OWID_SAM    366
# VAT         353
# TLS         337
# LAO         335
# KNA         334
# DMA         292
# VCT         279
# GRD         275
# LCA         237
# ATG         200
# LIE         175
# BTN         148
# BLZ         138
# PNG         137
# SLB         133
# GMB         127
# SYC         120
# BRB         118
# MHL         117
# MCO         115
# NAM         105
# NPL         105
#            ...
# KGZ          15
# KAZ          15
# UZB          15
# IDN          15
# COL          14
# BGR          14
# SAU          14
# VEN          14
# NOR          14
# GHA          14
# AUT          14
# SVK          14
# NLD          13
# PER          13
# QAT          13
# PAN          12
# POL          12
# MUS          12
# MAC          11
# AIA          11
# TUR          10
# IRN           9
# OWID_NCY      9
# FLK           9
# ...

# %%
data[data.total_vaccinations > 0].iso_code.value_counts()
# Out:
# OWID_WRL    67
# ISR         65
# CHL         60
# CZE         57
# ITA         57
# OWID_EUN    57
# DEU         57
# FRA         56
# BHR         56
# SVN         56
# DNK         56
# ROU         56
# NOR         54
# EST         54
# MEX         53
# POL         53
# BEL         52
# HUN         52
# GRC         51
# LTU         50
# BGR         50
# USA         50
# SVK         48
# GBR         46
# ARE         45
# FIN         42
# OMN         41
# GIB         40
# TUR         39
# AUT         39
#             ..
# ZAF          4
# LIE          4
# ECU          4
# JEY          4
# KWT          3
# PAK          3
# KHM          3
# JPN          3
# GGY          3
# NZL          2
# MAC          2
# IRN          2
# AIA          2
# DZA          2
# OWID_NCY     2
# LBN          2
# MMR          2
# NPL          2
# MUS          2
# QAT          2
# DOM          1
# BLR          1
# GUY          1
# GRL          1
# FLK          1
# EGY          1
# SHN          1
# ...

# %%
values = {
    'total_cases': 0, 
    'new_cases': 0, 
    'new_cases_smoothed': 0,
    'total_deaths': 0, 
    'new_deaths': 0,
    'new_deaths_smoothed': 0,
    'total_cases_per_million': 0,
    'new_cases_per_million': 0,
    'new_cases_smoothed_per_million': 0,
    'total_deaths_per_million': 0,
    'new_deaths_per_million': 0,
    'new_deaths_smoothed_per_million': 0,
    'total_vaccinations': 0,
    'people_vaccinated': 0,
    'people_fully_vaccinated': 0,
    'new_vaccinations': 0,
    'new_vaccinations_smoothed': 0,
    'total_vaccinations_per_hundred': 0,
    'people_vaccinated_per_hundred': 0,
    'people_fully_vaccinated_per_hundred': 0,
    'new_vaccinations_smoothed_per_million': 0}

data.fillna(value=values, inplace=True)
data.isna().sum()
# Out:
# iso_code                                     0
# continent                                 3508
# location                                     0
# date                                         0
# total_cases                                  0
# new_cases                                    0
# new_cases_smoothed                           0
# total_deaths                                 0
# new_deaths                                   0
# new_deaths_smoothed                          0
# total_cases_per_million                      0
# new_cases_per_million                        0
# new_cases_smoothed_per_million               0
# total_deaths_per_million                     0
# new_deaths_per_million                       0
# new_deaths_smoothed_per_million              0
# reproduction_rate                        13887
# icu_patients                             62971
# icu_patients_per_million                 62971
# hosp_patients                            61562
# ...

# %%
data[data.population.isna()].iso_code.value_counts()
# Out:
# OWID_INT    381
# OWID_NCY      9
# Name: iso_code, dtype: int64

# %%
data[data.population_density.isna()].iso_code.value_counts()
# Out:
# TWN         403
# OWID_NAM    397
# OWID_ASI    397
# OWID_EUN    396
# OWID_EUR    396
# OWID_OCE    394
# OWID_INT    381
# OWID_AFR    375
# OWID_SAM    366
# VAT         353
# SYR         337
# SSD         323
# GGY          22
# JEY          22
# AIA          11
# FLK           9
# OWID_NCY      9
# SHN           1
# Name: iso_code, dtype: int64

# %%
len(data[data.iso_code == 'JEY'])
# Out:
# 22

# %%
data[data.continent.isna()].head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 364  OWID_AFR       NaN   Africa  2020-02-13          0.0        0.0
# 365  OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# 366  OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# 367  OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# 368  OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 364                 0.0           0.0         0.0                  0.0
# 365                 0.0           0.0         0.0                  0.0
# 366                 0.0           0.0         0.0                  0.0
# 367                 0.0           0.0         0.0                  0.0
# 368                 0.0           0.0         0.0                  0.0
#
#               ...             gdp_per_capita  extreme_poverty  \
# ...

# %%
data[data.continent.isna()].iso_code.value_counts()
# Out:
# OWID_NAM    397
# OWID_ASI    397
# OWID_WRL    397
# OWID_EUN    396
# OWID_EUR    396
# OWID_OCE    394
# OWID_INT    381
# OWID_AFR    375
# OWID_SAM    366
# OWID_NCY      9
# Name: iso_code, dtype: int64

# %%
data.continent.value_counts()
# Out:
# Africa           18518
# Europe           17036
# Asia             16870
# North America     8248
# South America     4301
# Oceania           1963
# Name: continent, dtype: int64

# %%
summary_data = data[data.continent.isna()]
cleaned_data = data.drop(summary_data.index)
summary_data.head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 364  OWID_AFR       NaN   Africa  2020-02-13          0.0        0.0
# 365  OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# 366  OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# 367  OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# 368  OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 364                 0.0           0.0         0.0                  0.0
# 365                 0.0           0.0         0.0                  0.0
# 366                 0.0           0.0         0.0                  0.0
# 367                 0.0           0.0         0.0                  0.0
# 368                 0.0           0.0         0.0                  0.0
#
#               ...             gdp_per_capita  extreme_poverty  \
# ...
